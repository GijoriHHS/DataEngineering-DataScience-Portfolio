# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
tf.random.set_seed(100)

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

import numpy as np

# %%
df = sns.load_dataset('mpg')
print(df.shape)
df.describe(include='all')
# Out:
# (398, 9)
#                mpg   cylinders  displacement  horsepower       weight  \
# count   398.000000  398.000000    398.000000  392.000000   398.000000
# unique         NaN         NaN           NaN         NaN          NaN
# top            NaN         NaN           NaN         NaN          NaN
# freq           NaN         NaN           NaN         NaN          NaN
# mean     23.514573    5.454774    193.425879  104.469388  2970.424623
# std       7.815984    1.701004    104.269838   38.491160   846.841774
# min       9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%      17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%      23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%      29.000000    8.000000    262.000000  126.000000  3608.000000
# max      46.600000    8.000000    455.000000  230.000000  5140.000000
#
#         acceleration  model_year origin        name
# count     398.000000  398.000000    398         398
# unique           NaN         NaN      3         305
# top              NaN         NaN    usa  ford pinto
# freq             NaN         NaN    249           6
# mean       15.568090   76.010050    NaN         NaN
# std         2.757689    3.697627    NaN         NaN
# min         8.000000   70.000000    NaN         NaN
# 25%        13.825000   73.000000    NaN         NaN
# 50%        15.500000   76.000000    NaN         NaN
# 75%        17.175000   79.000000    NaN         NaN
# max        24.800000   82.000000    NaN         NaN

# %%
df['horsepower'].fillna(df['horsepower'].median(), inplace=True)
df = df.drop(['name'], axis=1)
df = pd.get_dummies(df, columns=['cylinders'], drop_first=True, prefix='Cylinder')
df = pd.get_dummies(df, columns=['model_year'], drop_first=True, prefix='Year')
df = pd.get_dummies(df, columns=['origin'], drop_first=True, prefix='Origin')
df.head()
# Out:
# C:\Users\Gijor\AppData\Local\Temp\ipykernel_5140\3318664815.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['horsepower'].fillna(df['horsepower'].median(), inplace=True)
#     mpg  displacement  horsepower  weight  acceleration  Cylinder_4  \
# 0  18.0         307.0       130.0    3504          12.0       False
# 1  15.0         350.0       165.0    3693          11.5       False
# 2  18.0         318.0       150.0    3436          11.0       False
# 3  16.0         304.0       150.0    3433          12.0       False
# 4  17.0         302.0       140.0    3449          10.5       False
#
#    Cylinder_5  Cylinder_6  Cylinder_8  Year_71  ...  Year_75  Year_76  \
# 0       False       False        True    False  ...    False    False
# 1       False       False        True    False  ...    False    False
# 2       False       False        True    False  ...    False    False
# 3       False       False        True    False  ...    False    False
# 4       False       False        True    False  ...    False    False
#
#    Year_77  Year_78  Year_79  Year_80  Year_81  Year_82  Origin_japan  \
# 0    False    False    False    False    False    False         False
# 1    False    False    False    False    False    False         False
# 2    False    False    False    False    False    False         False
# 3    False    False    False    False    False    False         False
# 4    False    False    False    False    False    False         False
#
#    Origin_usa
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#
# [5 rows x 23 columns]

# %%
target_variable = ['mpg'] 
predictors = list(set(list(df.columns))-set(target_variable))
df[predictors] = df[predictors]/df[predictors].max()
df.describe()
# Out:
#               mpg
# count  398.000000
# mean    23.514573
# std      7.815984
# min      9.000000
# 25%     17.500000
# 50%     23.000000
# 75%     29.000000
# max     46.600000

# %%
X = df[predictors].values.astype('float32')
y = df[target_variable].values.astype('float32')

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=100)

# %%
print(X_train.shape); print(X_test.shape)
# Out:
# (278, 22)
# (120, 22)

# %%
# define model
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(32, input_shape = (X_train.shape[1],), activation = 'relu'))
model.add(tf.keras.layers.Dense(16, activation= "relu"))
model.add(tf.keras.layers.Dense(8, activation= "relu"))
model.add(tf.keras.layers.Dense(4, activation= "relu"))
model.add(tf.keras.layers.Dense(1))
# Out:
# c:\Users\Gijor\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)
model.compile(loss = 'mae', metrics = ['mae'], optimizer = optimizer)

# %%
print("X_train dtype:", X_train.dtype)  # Let op: .dtype (niet .dtypes)
print("y_train dtype:", y_train.dtype)

model.fit(X_train, y_train, epochs=50)
# Out:
# X_train dtype: float32
# y_train dtype: float32
# Epoch 1/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 23.5194 - mae: 23.5194
# Epoch 2/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 22.8561 - mae: 22.8561
# Epoch 3/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 20.4243 - mae: 20.4243
# Epoch 4/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11.0016 - mae: 11.0016
# Epoch 5/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.1641 - mae: 8.1641
# Epoch 6/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3185 - mae: 4.3185
# Epoch 7/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7324 - mae: 3.7324
# Epoch 8/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1843 - mae: 3.1843
# Epoch 9/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9937 - mae: 2.9937
# Epoch 10/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7892 - mae: 2.7892
# Epoch 11/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6669 - mae: 2.6669
# Epoch 12/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5974 - mae: 2.5974
# Epoch 13/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4736 - mae: 2.4736
# Epoch 14/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6148 - mae: 2.6148
# Epoch 15/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5036 - mae: 2.5036
# Epoch 16/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3302 - mae: 2.3302
# Epoch 17/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4354 - mae: 2.4354
# Epoch 18/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5662 - mae: 2.5662
# Epoch 19/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4140 - mae: 2.4140
# Epoch 20/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2910 - mae: 2.2910
# Epoch 21/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2751 - mae: 2.2751
# Epoch 22/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5146 - mae: 2.5146
# Epoch 23/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3901 - mae: 2.3901
# Epoch 24/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2028 - mae: 2.2028
# Epoch 25/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1687 - mae: 2.1687
# Epoch 26/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2812 - mae: 2.2812
# Epoch 27/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5071 - mae: 2.5071
# Epoch 28/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2549 - mae: 2.2549
# Epoch 29/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1116 - mae: 2.1116
# Epoch 30/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1366 - mae: 2.1366
# Epoch 31/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3867 - mae: 2.3867
# Epoch 32/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3906 - mae: 2.3906
# Epoch 33/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1656 - mae: 2.1656
# Epoch 34/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0387 - mae: 2.0387
# Epoch 35/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0887 - mae: 2.0887
# Epoch 36/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2504 - mae: 2.2504
# Epoch 37/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3137 - mae: 2.3137
# Epoch 38/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1487 - mae: 2.1487
# Epoch 39/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9755 - mae: 1.9755
# Epoch 40/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9244 - mae: 1.9244
# Epoch 41/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1733 - mae: 2.1733
# Epoch 42/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2981 - mae: 2.2981
# Epoch 43/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1391 - mae: 2.1391
# Epoch 44/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9809 - mae: 1.9809
# Epoch 45/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8496 - mae: 1.8496
# Epoch 46/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0035 - mae: 2.0035
# Epoch 47/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2813 - mae: 2.2813
# Epoch 48/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0184 - mae: 2.0184
# Epoch 49/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8514 - mae: 1.8514
# Epoch 50/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7609 - mae: 1.7609

# %%
print(model.evaluate(X_train, y_train))
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9481 - mae: 1.9481
# [1.967771291732788, 1.967771291732788]

# %%
print(model.evaluate(X_test, y_test))
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4482 - mae: 2.4482
# [2.5639069080352783, 2.5639069080352783]

# %%
from sklearn.metrics import r2_score
pred_train = model.predict(X_train)
r2_score(y_train, pred_train)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 0.8853447437286377

# %%
pred_test = model.predict(X_test)
r2_score(y_test, pred_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 0.7917637825012207
